# %%
import requests
import json

# %%
api_token = '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'
session = requests.Session()
session.headers['Authorization'] = 'token %s' % api_token
session.headers['Accept'] = 'application/vnd.github.v3+json'

# %%
url = 'https://api.github.com/repos/kubernetes/kubernetes/issues?per_page=100'

# %%
result = session.get(url)

# %%
result.status_code
# Out:
# 200

# %%
all_issues_url = 
results_path = 'C:\\Users\\Pavel\\Documents\\data\\github'

# %%
import os

# %%
os.path.join(results_path, 'issues', f'page_{page_num}.json')

# %%
page_num = 1
stop = False
results = []

while not stop:
    url = f'https://api.github.com/repos/kubernetes/kubernetes/issues?state=all&per_page=100&page={page_num}'
    result = session.get(url)
    if result.status_code == 200:
        results_json = json.loads(result.content)
        with open(f'{results_path}page_{page_num}.json', 'w') as f:
            json.dump(results_json, f)
        print(f'done with page number {page_num}')
    elif result.status_code > 200:
        print('Something got wrong')

    if len(results_json) < 100:
        stop = True

    page_num += 1
# Out:
# done with page number 1
# done with page number 2
# done with page number 3
# done with page number 4
# done with page number 5
# done with page number 6
# done with page number 7
# done with page number 8
# done with page number 9
# done with page number 10
# done with page number 11
# done with page number 12
# done with page number 13
# done with page number 14
# done with page number 15
# done with page number 16
# done with page number 17
# done with page number 18
# done with page number 19
# done with page number 20
# done with page number 21
# done with page number 22
# done with page number 23
# done with page number 24
# done with page number 25
# done with page number 26
# done with page number 27
# done with page number 28
# done with page number 29
# done with page number 30
# done with page number 31
# done with page number 32
# done with page number 33
# done with page number 34
# done with page number 35
# done with page number 36
# done with page number 37
# ...

# %%
len(results_json)
# Out:
# 30
